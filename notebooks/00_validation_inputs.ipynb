# %% [markdown]
# # ValSKA-HERA-beam-FWHM validation inputs
#
# This notebook illustrates and describes the inputs to the validation analysis.
#
# This includes:
# * **Sky Model Plots**:
#   * Current results use GSM-based uvh5 files, so ideally, we should include either GSM or GSM+GLEAM.
#   * It would also be good to run / start running power spectrum analyses of the latter once available.
# * **Instrument Plots**:
#   * Antenna layout
#   * UV coverage
#   * Beam, including perturbation illustrations (c.f. PI27 progress plenary plots)
# * **Data Visualizations**: Potentially including (TBD, but beneficial to have on Confluence, at least):
#   * Dirty beam
#   * Dirty image
#   * Delay spectrum (if not too time-consuming)
